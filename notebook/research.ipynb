# %%
import pandas as pd
import numpy as np

# %%
books=pd.read_csv('BX-Books.csv',sep=';',encoding='latin-1',on_bad_lines='skip')
# Out:
# c:\Users\spsak\.conda\envs\books\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
books.head(3)
# Out:
#          ISBN            Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018          Clara Callan  Richard Bruce Wright                2001
# 2  0060973129  Decision in Normandy          Carlo D'Este                1991
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2          HarperPerennial  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.loc[500,'Image-URL-L']
# Out:
# 'http://images.amazon.com/images/P/0380973545.01.LZZZZZZZ.jpg'

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books.drop(columns=['Image-URL-S', 'Image-URL-M'],inplace=True)

# %%
books.sample(2)
# Out:
#               ISBN                             Book-Title  \
# 28038   0312113102  Liliane: Resurrection of the Daughter
# 187606  0941543188                    My Brain Escapes Me
#
#                 Book-Author Year-Of-Publication      Publisher  \
# 28038        Ntozake Shange                1994  St Martins Pr
# 187606  Robert Steven Rhine                1999  Sun Dog Press
#
#                                               Image-URL-L
# 28038   http://images.amazon.com/images/P/0312113102.0...
# 187606  http://images.amazon.com/images/P/0941543188.0...

# %%
books.rename(columns={'Book-Title':'title', 'Book-Author':'author', 'Year-Of-Publication':'year', 'Publisher':'publisher', 'Image-URL-L':'image_url'},inplace=True)

# %%
books
# Out:
#               ISBN                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
users=pd.read_csv('BX-Users.csv',sep=';',encoding='latin-1',on_bad_lines='skip')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
users.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
users.rename(columns={'User-ID':'user_id', 'Location':'location', 'Age':'age'},inplace=True)

# %%
users.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings=pd.read_csv('BX-Book-Ratings.csv',sep=';',encoding='latin-1',on_bad_lines='skip')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.rename(columns={'User-ID':'user_id', 'ISBN':'ISBN', 'Book-Rating':'rating'},inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
print(f'shape of books:{books.shape} \nshape of users:{users.shape} \nshape of ratings:{ratings.shape}')
# Out:
# shape of books:(271360, 6)
# shape of users:(278858, 3)
# shape of ratings:(1149780, 3)

# %%
ratings['user_id'].value_counts()[276729]
# Out:
# 2

# %%
ratings[ratings['user_id'] == 276729]
# Out:
#    user_id        ISBN  rating
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
active_users=ratings['user_id'].value_counts()>200

# %%
active_users
# Out:
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: user_id, Length: 105283, dtype: bool

# %%
active_users[active_users].shape
# Out:
# (899,)

# %%
active_users_index=active_users[active_users].index

# %%
active_users_index
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727,
#             268622, 188951],
#            dtype='int64', length=899)

# %%
ratings=ratings[ratings['user_id'].isin(active_users_index)]

# %%
ratings
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
books
# Out:
#               ISBN                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
books.columns
# Out:
# Index(['ISBN', 'title', 'author', 'year', 'publisher', 'image_url'], dtype='object')

# %%
ratings_with_books=ratings.merge(books,on='ISBN')

# %%
ratings_with_books
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 1          3363  002542730X       0
# 2         11676  002542730X       6
# 3         12538  002542730X      10
# 4         13552  002542730X       0
# ...         ...         ...     ...
# 487666   275970  1892145022       0
# 487667   275970  1931868123       0
# 487668   275970  3411086211      10
# 487669   275970  3829021860       0
# 487670   275970  4770019572       0
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 487666                                   Here Is New York
# ...

# %%
# final_books=ratings_with_books.merge(users,on='user_id')

# %%
# final_books.head(3)

# %%
number_rating=ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating
# Out:
#                                                     title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       2
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Beyond IBM: Leadership Marketing and Finance ...       1
# 4        Clifford Visita El Hospital (Clifford El Gran...       1
# ...                                                   ...     ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...       3
# 160265                                      Ã?Â?lpiraten.       1
# 160266                     Ã?Â?rger mit Produkt X. Roman.       1
# 160267                              Ã?Â?stlich der Berge.       1
# 160268                                  Ã?Â?thique en toc       1
#
# [160269 rows x 2 columns]

# %%
number_rating.rename(columns={'rating':'num_of_rating'},inplace=True)

# %%
number_rating
# Out:
#                                                     title  num_of_rating
# 0        A Light in the Storm: The Civil War Diary of ...              2
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Beyond IBM: Leadership Marketing and Finance ...              1
# 4        Clifford Visita El Hospital (Clifford El Gran...              1
# ...                                                   ...            ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...              3
# 160265                                      Ã?Â?lpiraten.              1
# 160266                     Ã?Â?rger mit Produkt X. Roman.              1
# 160267                              Ã?Â?stlich der Berge.              1
# 160268                                  Ã?Â?thique en toc              1
#
# [160269 rows x 2 columns]

# %%
final_rating=ratings_with_books.merge(number_rating,on='title')

# %%
final_rating.head(3)
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
#
#                                            image_url  num_of_rating
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/002542730X.0...             82
# 2  http://images.amazon.com/images/P/002542730X.0...             82

# %%
final_rating=final_rating[final_rating['num_of_rating']>=50]

# %%
final_rating.sample(3)
# Out:
#        user_id        ISBN  rating  \
# 47078   203240  0151191530       0
# 8240     39646  0446602620       0
# 8929    258534  0449221504       9
#
#                                                    title            author  \
# 47078                                   The Color Purple      Alice Walker
# 8240                                          Blood Work  Michael Connelly
# 8929   K Is for Killer (Kinsey Millhone Mysteries (Pa...       Sue Grafton
#
#        year      publisher                                          image_url  \
# 47078  1982   Harcourt Inc  http://images.amazon.com/images/P/0151191530.0...
# 8240   1998   Warner Books  http://images.amazon.com/images/P/0446602620.0...
# 8929   1999  Fawcett Books  http://images.amazon.com/images/P/0449221504.0...
#
#        num_of_rating
# 47078            118
# 8240              54
# 8929              79

# %%
final_rating['num_of_rating'].unique()
# Out:
# array([ 82, 133, 108,  79,  77,  91, 103, 209, 105, 115,  55, 114, 116,
#         68, 270, 146,  53,  83, 137,  66,  86,  94,  78,  84, 180, 142,
#         71,  58, 224, 120,  61, 136,  67,  52,  56, 121,  64, 123, 183,
#        138,  62,  81, 159, 186, 171, 149,  54, 150, 124,  95, 148,  80,
#        132,  93,  90,  50, 126,  87,  51,  92,  70, 111,  73,  57, 363,
#        135,  96, 140, 182, 175, 130, 118, 127, 122,  69,  63,  97, 210,
#        236, 213, 119,  89,  88,  60, 112, 101,  65, 110, 228,  85, 104,
#        151,  74, 227,  76, 179,  59,  72, 188, 169, 134, 161, 241, 212,
#         98, 100, 277, 174, 131, 125,  99, 107, 128, 206, 181, 168, 117,
#        109, 113, 145, 200, 230, 177, 143,  75, 185, 163, 129, 162, 193],
#       dtype=int64)

# %%
print(final_rating.duplicated(subset=['user_id']).sum())
# Out:
# 60965

# %%
dup_cols=[col for col in final_rating.columns if final_rating[col].duplicated().any()]
print(dup_cols)
# Out:
# ['user_id', 'ISBN', 'rating', 'title', 'author', 'year', 'publisher', 'image_url', 'num_of_rating']

# %%
final_rating.isnull().sum()
# Out:
# user_id          0
# ISBN             0
# rating           0
# title            0
# author           0
# year             0
# publisher        0
# image_url        0
# num_of_rating    0
# dtype: int64

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse=csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14942 stored elements in Compressed Sparse Row format>

# %%
type(book_sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
book_pivot.iloc[237,:]
# Out:
# user_id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    9.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: Harry Potter and the Chamber of Secrets (Book 2), Length: 888, dtype: float64

# %%
distance , suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 68.78953409, 69.5413546 , 72.64296249, 76.83098333,
#         77.28518616]])

# %%
suggestion
# Out:
# array([[237, 240, 238, 241, 184, 536]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#        'The Cradle Will Fall'],
#       dtype='object', name='title')

# %%
book_names=book_pivot.index

# %%
ids=np.where(final_rating['title']=='Harry Potter and the Chamber of Secrets (Book 2)')[0][0]

# %%
final_rating.iloc[ids]['image_url']
# Out:
# 'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'

# %%
book_name = []
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])

# %%
book_name
# Out:
# [Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#         'Harry Potter and the Prisoner of Azkaban (Book 3)',
#         'Harry Potter and the Goblet of Fire (Book 4)',
#         'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#         'The Cradle Will Fall'],
#        dtype='object', name='title')]

# %%
ids_index=[]
for name in book_name[0]:
    ids=np.where(final_rating['title']==name)[0][0]
    ids_index.append(ids)

# %%
ids_index
# Out:
# [4364, 4537, 25119, 4670, 41785, 56125]

# %%
for idx in ids_index:
    url=final_rating.iloc[idx]['image_url']
    print(url)
# Out:
# http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0439136369.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0439139597.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/043936213X.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0446604232.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0440115450.01.LZZZZZZZ.jpg

# %%
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(book_name,open('artifacts/book_name.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommened_book(book_name):
    book_id=np.where(book_pivot.index==book_name)[0][0]
    distance , suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

    for i in range(len(suggestion)):
        books=book_pivot.index[suggestion[i]]
        for j in books:
            if j ==book_name:
                print(f"you searched {book_name}\n")
                print(f"suggestion books are:\n")
            else:
                print(j)

# %%
book_name='Harry Potter and the Chamber of Secrets (Book 2)'
recommened_book(book_name)
# Out:
# you searched Harry Potter and the Chamber of Secrets (Book 2)
#
# suggestion books are:
#
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# The Cradle Will Fall

# %%
book_name
# Out:
# [Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#         'Harry Potter and the Prisoner of Azkaban (Book 3)',
#         'Harry Potter and the Goblet of Fire (Book 4)',
#         'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#         'The Cradle Will Fall'],
#        dtype='object', name='title')]
